# %%
import pathlib
import os
import GPX_stat4windsurfer.gpxo_enhance as gpxo_enhance

directory_path = pathlib.Path(r'C:\Users\wp\Documents\GitHub\GPX_stat4windsurfer\GPX_stat4windsurfer\data')
extension = "gpx"  # Example: find all .txt files

files_with_extension = gpxo_enhance.list_files_with_extension(directory_path, extension)

for file in files_with_extension:
    track = gpxo_enhance.track_enhance( file)
    performance_report = track.print_results()
